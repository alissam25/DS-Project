# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\aliss\DS-Project\WINEDATA_CLEAN.csv')
df
# Out:
#                                                     Name  Regular Price  \
# 0        2020 Eisele Vineyard Pickett Cabernet Sauvignon          84.94
# 1      2019 Beaulieu Vineyard Private Reserve Georges...         169.94
# 2      2017 Robert Mondavi Winery Cabernet Sauvignon ...         159.94
# 3            2019 Sinegal Napa Valley Cabernet Sauvignon          89.94
# 4      2020 Domaine Francois Gaunoux Meursault Clos d...          84.94
# ...                                                  ...            ...
# 31506                        2002 Ruinart Blanc de Blanc         325.00
# 31507  2018 Jean et Sebastien Dauvissat Les Preuses C...          94.94
# 31508              2018 Clos Fourtet Closerie de Fourtet          44.94
# 31509                            2003 Krohn Vintage Port          74.94
# 31510  2011 Louis Jadot Gevrey Chambertin Petite Chap...         124.94
#
#        Rebate price Type & Color             Variety   Country      Region  \
# ...

# %%
#OUTLIERS
#super high prices- what do they have in common?
df["Regular Price"].describe()
Q1 = np.percentile(df["Regular Price"], 25)
Q3 = np.percentile(df["Regular Price"], 75)
IQR = Q3 - Q1
Fare_outlier_rows = df[(df["Regular Price"] < Q1 - 1.5*IQR) | (df["Regular Price"] > Q3 + 1.5*IQR )]
Fare_outlier_rows.sort_values("Regular Price")
Fare_outlier_rows["Regular Price"].min()

sns.boxplot(Fare_outlier_rows["Regular Price"])
# Out:
# <AxesSubplot:xlabel='Regular Price'>
